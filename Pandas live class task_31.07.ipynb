# %% [markdown]
# ## Task 1 - Fitbit Dataset

# %% [markdown]
# ### 1. Read this dataset in pandas , mysql and mongodb

# %%
#read fitbit data in pandas
import pandas as pd
import mysql.connector as conn
import pymongo
df_fitbit=pd.read_csv('FitBit.csv')
df_fitbit.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %% [markdown]
# ## 2 . while loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table

# %%
#bulk insert the csv file in mysql database
from sqlalchemy import create_engine as ce
import pymysql
engine=ce('mysql+pymysql://root:MySqlRoot!3456@localhost:3306/fitbit')
df_fitbit.to_sql('fitbit_table1',engine)

# %%
#read data from mysql fitbit_table
import mysql.connector as conn
mydb=conn.connect(host="localhost",user="root", passwd="MySqlRoot!3456",use_pure=True)
cur=mydb.cursor()
cur.execute('use fitbit')
cur.execute('select*from fitbit_table')
res=cur.fetchall()
cur1=mydb.cursor()
cur1.execute('show columns from fitbit_table')
res1=cur1.fetchall()
cols=[]
for c in res1:
    cols.append(c[0])
df_fitbit_mysql=pd.DataFrame(res,columns=cols)
df_fitbit_mysql.head()
# Out:
#    index          Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0      0  1503960366    3/25/2016       11004           7.11             7.11
# 1      1  1503960366    3/26/2016       17609          11.55            11.55
# 2      2  1503960366    3/27/2016       12736           8.53             8.53
# 3      3  1503960366    3/28/2016       13231           8.93             8.93
# 4      4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
# ...

# %%
#insert and read this data in MongoDb
import pymongo
import json
fitbit_json=df_fitbit.to_json()
client=pymongo.MongoClient("mongodb+srv://subhomongo1234:Mongo1234@cluster0.lnddv.mongodb.net/?retryWrites=true&w=majority")
db=client.test
print(db)
db=client['FitBit']
coll=db['fitbit tracker']
coll.insert_many([json.loads(fitbit_json)])
# Out:
# Database(MongoClient(host=['cluster0-shard-00-00.lnddv.mongodb.net:27017', 'cluster0-shard-00-01.lnddv.mongodb.net:27017', 'cluster0-shard-00-02.lnddv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-2ok300-shard-0', tls=True), 'test')

# %%
#read data from mongodb
for i in coll.find():
    #print(i) # did not print the result on purpose as it will take a lot of space in the notebook 
    #and will be difficult to upload in github
# Out:
#   Input In [315]
#     #print(i)
#              ^
# IndentationError: expected an indented block

# %% [markdown]
# ## 3. convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format

# %%
df_fitbit['ActivityDate']=pd.to_datetime(df_fitbit['ActivityDate'])
df_fitbit.dtypes
# Out:
# Id                                   int64
# ActivityDate                datetime64[ns]
# TotalSteps                           int64
# TotalDistance                      float64
# TrackerDistance                    float64
# LoggedActivitiesDistance           float64
# VeryActiveDistance                 float64
# ModeratelyActiveDistance           float64
# LightActiveDistance                float64
# SedentaryActiveDistance            float64
# VeryActiveMinutes                    int64
# FairlyActiveMinutes                  int64
# LightlyActiveMinutes                 int64
# SedentaryMinutes                     int64
# Calories                             int64
# dtype: object

# %% [markdown]
# ## 4 . Find out in this data that how many unique id's we have

# %%
df_fitbit.Id.unique() #we can do len(df_fitbit.Id.unique()) if we want the count of the unique IDs
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        2891001357, 3372868164, 3977333714, 4020332650, 4057192912,
#        4319703577, 4388161847, 4445114986, 4558609924, 4702921684,
#        5553957443, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8253242879, 8378563200, 8583815059, 8792009665, 8877689391],
#       dtype=int64)

# %% [markdown]
# ## 5 . which id is one of the active id that you have in whole dataset

# %%
df_fitbit
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
#method1: counting total steps for each day
df_fitbit.groupby('Id').sum('TotalSteps').sort_values('TotalSteps',ascending=False)
# Out:
#             TotalSteps  TotalDistance  TrackerDistance  \
# Id
# 1503960366      221170     144.540001       144.540001
# 8877689391      209005     169.089998       169.089998
# 4020332650      184851     132.600000       132.600000
# 6962181067      176956     121.070000       117.400001
# 8053475328      163288     127.340000       127.340000
# 7007744171      147124     106.280000        98.440000
# 2347167796      147001      97.670001        97.670001
# 2022484408      146099     105.290001       105.290001
# 4702921684      119151      96.690000        96.690000
# 3977333714      103967      69.679999        69.679999
# 5553957443      100257      65.500000        65.500000
# 8378563200       97623      77.420000        77.420000
# 5577150313       94690      70.930000        70.930000
# 4319703577       93847      63.070000        63.070000
# 1644430081       92748      67.490000        67.490000
# 6117666160       82486      62.270000        62.270000
# ...

# %%
#find out the top id from the above groupby dataset
a=df_fitbit.groupby('Id').sum('TotalSteps').sort_values('TotalSteps',ascending=False)
a.index[0]
# Out:
# 1503960366

# %%
#method2 using least sedentary minutes
b=df_fitbit.groupby('Id').sum('SedentaryMinutes').sort_values('SedentaryMinutes')
b.index[0]
# Out:
# 5553957443

# %% [markdown]
# ## 6 . how many of them have not logged there activity find out in terms of number of ids

# %%
c=df_fitbit.groupby('Id').sum('LoggedActivitiesDistance')
len(c[c['LoggedActivitiesDistance']==0].index)
# Out:
# 29

# %% [markdown]
# ## 7 . Find out who is the laziest person id that we have in dataset

# %%
df_fitbit['TotalActiveMinutes']=df_fitbit[['VeryActiveMinutes','FairlyActiveMinutes','LightlyActiveMinutes']].agg(sum,axis=1)

# %%
a1=df_fitbit.groupby('Id').sum('TotalActiveMinutes').sort_values('TotalActiveMinutes')
a1.head()
# Out:
#             TotalSteps  TotalDistance  TrackerDistance  \
# Id
# 4388161847           0           0.00             0.00
# 6391747486       12032           9.67             0.91
# 6290855005       16181          12.23            12.23
# 8253242879       28679          20.15            20.15
# 8583815059       24364          19.02            19.02
#
#             LoggedActivitiesDistance  VeryActiveDistance  \
# Id
# 4388161847                   0.00000                0.00
# 6391747486                   8.75483                2.03
# 6290855005                   0.00000                2.02
# 8253242879                   0.00000                7.24
# 8583815059                   0.00000                0.37
#
#             ModeratelyActiveDistance  LightActiveDistance  \
# Id
# 4388161847                      0.00                 0.00
# 6391747486                      0.05                 7.59
# 6290855005                      3.68                 6.53
# ...

# %%
a1.index[0] #ans
# Out:
# 4388161847

# %% [markdown]
# ## 8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset

# %%
a2=df_fitbit.groupby('Id').first()
len(a2[a2['Calories']>2250].index) #per day 2250 calories burn is considered as healthy
# Out:
# 15

# %% [markdown]
# ## 9. how many person are not a regular person with respect to activity try to find out those

# %%
q=df_fitbit[df_fitbit['TotalSteps']==0].groupby('Id').first()
len(q.index)
# Out:
# 14

# %% [markdown]
# ## 10 . who is the thired most active person in this dataset find out those in pandas and in sql both .

# %%
a3=df_fitbit.groupby('Id').sum('TotalActiveMinutes').sort_values('TotalActiveMinutes',ascending=False)
a3.nlargest(3,'TotalActiveMinutes').index[2]
# Out:
# 6962181067

# %%
#In Sql the query should be
select id, VeryActiveMinutes+FairlyActiveMinutes+LightlyActiveMinutes as TotalActiveMinutes from fitbit_table1 group by id order by TotalActiveMinutes desc limit 1 offset 2

# %% [markdown]
# ## 11 . who is the 5th most laziest person avilable in dataset find it out

# %%
a1.nlargest(5,'TotalActiveMinutes').index[4]
# Out:
# 7007744171

# %% [markdown]
# ## 12 . what is a totla acumulative calories burn for a person find out

# %%
df_fitbit.groupby('Id',as_index=False).sum()[['Id','Calories']]
# Out:
#             Id  Calories
# 0   1503960366     34128
# 1   1624580081     25705
# 2   1644430081     29164
# 3   1844505072     19391
# 4   1927972279     27048
# 5   2022484408     29704
# 6   2026352035     16266
# 7   2320127002     18385
# 8   2347167796     30320
# 9   2873212765     20349
# 10  2891001357     18187
# 11  3372868164     18603
# 12  3977333714     16777
# 13  4020332650     98412
# 14  4057192912     60913
# 15  4319703577     23931
# 16  4388161847     14442
# 17  4445114986     31617
# 18  4558609924     21962
# 19  4702921684     42322
# 20  5553957443     21630
# 21  5577150313     36303
# 22  6117666160     20993
# 23  6290855005     21656
# 24  6391747486     15868
# 25  6775888955     24523
# 26  6962181067     29249
# 27  7007744171     31525
# 28  7086361926     26124
# 29  8053475328     31825
# 30  8253242879     17556
# 31  8378563200     40274
# 32  8583815059     19130
# 33  8792009665     24884
# 34  8877689391     41414

# %% [markdown]
# # **Task 2- Superstore_USA dataset**

# %%
#converting the excel file into pandas dataframe
super=pd.ExcelFile('Superstore_USA.xlsx')

# %% [markdown]
# ## 1 . load this data in sql and in pandas with a relation in sql

# %%
super_orders=pd.read_excel(super,sheet_name='Orders')
super_returns=pd.read_excel(super,sheet_name='Returns')
super_users=pd.read_excel(super,sheet_name='Users')

# %%
df_orders=pd.DataFrame(super_orders)
df_returns=pd.DataFrame(super_returns)
df_users=pd.DataFrame(super_users)

# %%
df_orders
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %% [markdown]
# ## 2 . while loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table

# %%
#loading the dataset in SQL
from sqlalchemy import create_engine as ce
import pymysql
import mysql.connector as conn
mydb=conn.connect(host="localhost",user="root", passwd="MySqlRoot!3456",use_pure=True)
cur=mydb.cursor()
cur.execute('create database Superstore_USA')
cur.execute('use Superstore_USA')
my_engine=ce('mysql+pymysql://root:MySqlRoot!3456@localhost:3306/Superstore_USA')
df_orders.to_sql('superstore_order',my_engine,index=False)
df_returns.to_sql('superstore_returns',my_engine,index=False)
df_users.to_sql('super_users',my_engine,index=False)

# %% [markdown]
# ## 3 . Find out how return that we ahve recived and with a product id

# %%
df_returns
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
a=pd.merge(df_orders,df_returns)
a[a['Status']=='Returned'][['Order ID']]
# Out:
#     Order ID
# 0       9895
# 1      13959
# 2      13959
# 3      36038
# 4      39490
# ..       ...
# 93      7107
# 94      7107
# 95     42823
# 96     13638
# 97     47109
#
# [98 rows x 1 columns]

# %%
a.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'Status'],
#       dtype='object')

# %% [markdown]
# ## 4 . try  to join order and return data both in sql and pandas

# %%
#in pandas
pd.merge(df_orders,df_returns)
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
#in sql
#select r.`Order ID` from superstore_returns r inner join superstore_order o on r.`Order ID`=o.`Order ID`

# %% [markdown]
# ## 5 . Try to find out how many unique customer that we have

# %%
len(df_orders['Customer ID'].unique())
# Out:
# 2703

# %% [markdown]
# ## 6 . try to find out in how many regions we are selling a product and who is a manager for a respective region

# %%
df_orders.Region.unique()
# Out:
# array(['Central', 'West', 'East', 'South'], dtype=object)

# %%
df_users
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %% [markdown]
# ## 7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment

# %%
df_orders.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
count=[]
total_order=len(df_orders)
for i in df_orders['Ship Mode'].unique():
    c=len(df_orders[df_orders['Ship Mode']==i])
    count.append(c/total_order*100)
count
cols=list(df_orders['Ship Mode'].unique())
ship_percent=pd.DataFrame(list(zip(cols,count)),columns=['ship_mode','percentage'],index=None)
ship_percent
# Out:
#         ship_mode  percentage
# 0     Regular Air   74.644600
# 1     Express Air   11.744112
# 2  Delivery Truck   13.611288

# %% [markdown]
# ## 8 . Create a new coulmn and try to find our a diffrence between order date and shipment date

# %%
df_orders['DeliveryTime_in_days']=(df_orders['Ship Date']-df_orders['Order Date']).dt.days

# %%
df_orders[['Order Date','Ship Date','DeliveryTime_in_days']]
# Out:
#      Order Date  Ship Date  DeliveryTime_in_days
# 0    2012-05-28 2012-05-30                     2
# 1    2010-07-07 2010-07-08                     1
# 2    2011-07-27 2011-07-28                     1
# 3    2011-07-27 2011-07-28                     1
# 4    2011-07-27 2011-07-27                     0
# ...         ...        ...                   ...
# 9421 2013-05-14 2013-05-15                     1
# 9422 2013-05-14 2013-05-14                     0
# 9423 2013-09-12 2013-09-14                     2
# 9424 2010-02-08 2010-02-11                     3
# 9425 2013-09-12 2013-09-14                     2
#
# [9426 rows x 3 columns]

# %% [markdown]
# ## 9 . base on question number 8 find out for which order id we have shipment duration more than 10 days

# %%
df_orders[df_orders['DeliveryTime_in_days']>10][['Order ID','DeliveryTime_in_days']]
# Out:
#       Order ID  DeliveryTime_in_days
# 643      87215                    84
# 1548     86318                    11
# 1549     86318                    15
# 1678     87957                    17
# 1679     87957                    11
# 1680     87957                    28
# 1697     19556                    17
# 1698     19556                    11
# 1699     19556                    28
# 2515     86177                    92
# 5548     88223                    14
# 5673     88352                    17
# 5859     87572                    22
# 5881     91294                    24
# 8607     86434                    18
# 8609     86436                    17
# 8610     86436                    19
# 8973     87300                    19
# 8982     19841                    27
# 8983     19841                    31
# 8993     19841                    19
# 8996     87300                    27
# 8997     87300                    31

# %% [markdown]
# ## 10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well

# %%
merged=pd.merge(left=df_orders,right=df_returns,on='Order ID',indicator=True)
merged[['Order ID','DeliveryTime_in_days','Status']].sort_values('DeliveryTime_in_days',ascending=False) #no such order found
# Out:
#     Order ID  DeliveryTime_in_days    Status
# 25     51559                     9  Returned
# 88     32931                     7  Returned
# 43     41760                     7  Returned
# 42     41760                     5  Returned
# 44     41760                     5  Returned
# ..       ...                   ...       ...
# 63     13984                     0  Returned
# 15     17155                     0  Returned
# 92      7107                     0  Returned
# 4      39490                     0  Returned
# 67     41059                     0  Returned
#
# [98 rows x 3 columns]

# %% [markdown]
# ## 11 . Gorup by region and find out which region is more profitable

# %%
reg_prof=df_orders.groupby('Region',as_index=False).sum('Profit').sort_values('Profit',ascending=False)
reg_prof[['Region','Profit']] #Central region was most profitable
# Out:
#     Region         Profit
# 0  Central  519825.567067
# 1     East  377566.186045
# 3     West  310849.453897
# 2    South  104201.192420

# %% [markdown]
# ## 12 . Try to find out overalll in which country we are giving more didscount

# %%
df_orders.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'DeliveryTime',
#        'DeliveryTime_in_days'],
#       dtype='object')

# %%
# There is no 'Country' column so grouped by 'State or Province'
state_disc=df_orders.groupby('State or Province',as_index=False).sum('Discount')
state_disc[['State or Province','Discount']].sort_values('Discount',ascending=False) #California is the state with 
# where most discount was given
# Out:
#        State or Province  Discount
# 3             California     52.28
# 41                 Texas     31.36
# 11              Illinois     29.71
# 30              New York     28.86
# 8                Florida     26.38
# 33                  Ohio     19.71
# 45            Washington     15.48
# 20              Michigan     15.29
# 36          Pennsylvania     13.32
# 21             Minnesota     12.52
# 12               Indiana     12.22
# 31        North Carolina     12.02
# 19         Massachusetts     11.22
# 44              Virginia      9.80
# 9                Georgia      9.79
# 18              Maryland      8.85
# 28            New Jersey      8.73
# 40             Tennessee      8.55
# 35                Oregon      8.42
# 23              Missouri      8.09
# 47             Wisconsin      8.06
# 4               Colorado      8.05
# 42                  Utah      7.67
# 13                  Iowa      7.15
# 14                Kansas      6.89
# 1                Arizona      6.86
# ...

# %% [markdown]
# ## 13 . Give me a list of unique postal code

# %%
df_orders['Postal Code'].unique()
# Out:
# array([60101, 98221, 91776, ..., 61832, 62521, 26554], dtype=int64)

# %% [markdown]
# ## 14 . which customer segement is more profitalble find it out .

# %%
cust_seg=df_orders.groupby('Customer Segment',as_index=False).sum('Profit')
cust_seg[['Customer Segment','Profit']].sort_values('Profit',ascending=False) #Corporate is the ans
# Out:
#   Customer Segment         Profit
# 1        Corporate  505538.627783
# 3   Small Business  316474.592482
# 2      Home Office  283869.553814
# 0         Consumer  206559.625348

# %% [markdown]
# ## 15 . try to find out the 10th most loss making product catagory .

# %%
#There are only 3 Product Category so filteed using Product Sub-Category
prod_cat=df_orders.groupby('Product Sub-Category',as_index=False).sum('Profit')
prod_cat[['Product Sub-Category','Profit']].sort_values('Profit')
# Out:
#               Product Sub-Category         Profit
# 15                          Tables  -72495.061875
# 2                        Bookcases   -7708.748564
# 12                    Rubber Bands   -2841.722459
# 13   Scissors, Rulers and Trimmers   -1936.849120
# 11             Pens & Art Supplies    1195.902840
# 14          Storage & Organization    8078.804727
# 7                           Labels   17775.320505
# 10                           Paper   35361.621738
# 6                        Envelopes   46133.223840
# 4             Computer Peripherals   87917.842513
# 8               Office Furnishings   92209.225867
# 0                       Appliances  121651.391380
# 5                  Copiers and Fax  129156.684030
# 3               Chairs & Chairmats  165348.882760
# 9                  Office Machines  168072.833340
# 1   Binders and Binder Accessories  226572.523042
# 16    Telephones and Communication  297950.524866

# %%
a=prod_cat[['Product Sub-Category','Profit']].sort_values('Profit')
a.reset_index(drop=True,inplace=True)
a.loc[[9],:] #ans
# Out:
#    Product Sub-Category        Profit
# 9  Computer Peripherals  87917.842513

# %% [markdown]
# ## 16 . Try to find out 10 top  product with highest margins

# %%
product_name=df_orders.groupby('Product Name',as_index=False).first()
product_name[['Product Name','Product Base Margin']].sort_values('Product Base Margin',ascending=False).head(10)
# Out:
#                                            Product Name  Product Base Margin
# 88                                          Accessory27                 0.85
# 1010                  Sterling Rubber Bands by Alliance                 0.85
# 98                                           Accessory4                 0.85
# 821   Office Impressions Heavy Duty Welded Shelving ...                 0.85
# 256                    Belkin OmniView SE Rackmount Kit                 0.85
# 940   Serrated Blade or Curved Handle Hand Letter Op...                 0.84
# 1057  Tennsco Stur-D-Stor Boltless Shelving, 5 Shelv...                 0.84
# 1050                        Tennsco Commercial Shelving                 0.84
# 1052                        Tennsco Industrial Shelving                 0.83
# 330             Carina 42"Hx23 3/4"W Media Storage Unit                 0.83
